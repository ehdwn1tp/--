# %% [markdown]
# ### <b>실전 프로젝트 - CNN을 활용한 풍경(Scene) 이미지 분류</b>
#
# * 한 장의 풍경 이미지가 주어졌을 때, 어떠한 카테고리(category)에 속하는지 맞히는 <b>분류 모델</b>을 만드세요.
# * 다음의 세 가지 대표적인 CNN 모델을 실습합니다.
#     1. [LeNet (1998)](http://yann.lecun.com/exdb/publis/pdf/lecun-98.pdf)
#     2. [AlexNet (2012 NIPS)](https://papers.nips.cc/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf)
#     3. [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385)
# * 성능을 올릴 수 있는 두 가지 심화 기법을 실습합니다.
#     1. [Mixup (ICLR 2018)](https://arxiv.org/abs/1710.09412): 데이터 증진 기법의 일종으로 정확도를 높입니다.
#     2. Transfer Learning: 학습 속도와 정확도를 모두 향상시킬 수 있습니다.
# * 본 프로젝트는 <b>총 7개의 문제</b>로 구성됩니다.
#     * <b>Problem</b>이라고 명시된 부분의 소스코드만 작성합니다.
#     * <b>알아보기</b>라고 명시된 부분은 단순히 읽고 실행하면 됩니다.
#     * 단계적으로 문제를 풀어나가는 과정에서 CNN 기반의 고성능 분류 모델을 학습하는 방법을 이해할 수 있습니다.
# * (참고) 본 실습 코드에서는 빠른 결과 도출을 위해 30~50 epoch 정도만 학습합니다.
#     * 풍경 데이터셋에 대하여 완전히 학습시키기 위해서는 100 epoch 이상의 학습이 필요합니다.

# %% [markdown]
# #### <b>(알아보기) 지난 프로젝트 Review</b>
#
# * 지난 프로젝트에서는 Scene Classification 데이터셋에 대하여 간단한 기계학습 모델을 학습했습니다.
#     1. 선형 분류 모델(Linear Models for Classification)
#     2. KNN (K-Nearest Neighbors)
# * 하지만, 두 기법 모두 정확도(accuracy)가 <b>60% 미만</b>으로 낮게 나온다는 <b>한계점</b>이 존재했습니다.
# * 본 실습에서는 CNN을 이용해 정확도를 <b>최소한 90% 이상으로</b> 높입니다.
#     * 실제로 현업에서 많이 사용되는 테크닉을 이용해 최대한 정확도를 끌어올려 봅시다.

# %% [markdown]
# ## <b>Problem 1. 데이터셋 다운로드 및 분석하기</b>
#
# * [PyTorch용 Scene Classification 데이터셋 저장소](https://github.com/ndb796/Scene-Classification-Dataset-Split)
#     * 참고: [원본 Kaggle 데이터셋 링크](https://www.kaggle.com/nitishabharathi/scene-classification)
#     * 본 데이터셋은 <b>저작권이 없는(No Copyright)</b> [CC0: Public Domain](https://creativecommons.org/publicdomain/zero/1.0/) 라이센스를 따라므로, 자유롭게 변형할 수 있습니다.
# * PyTorch에서 곧바로 불러와 사용할 수 있도록 구성된 데이터셋입니다.
# * 다음의 명령어를 이용해 데이터셋을 다운로드할 수 있습니다.
#
# <pre>
# # 깃허브에서 데이터셋 다운로드하기
# !git clone https://github.com/ndb796/Scene-Classification-Dataset-Split
# # 폴더 안으로 이동
# %cd Scene-Classification-Dataset-Split
# </pre>

# %%
# 깃허브에서 데이터셋 다운로드하기
# !git clone https://github.com/ndb796/Scene-Classification-Dataset-Split
# 폴더 안으로 이동
# %cd Scene-Classification-Dataset-Split
# Out:
# Cloning into 'Scene-Classification-Dataset-Split'...
# remote: Enumerating objects: 17038, done.
# remote: Total 17038 (delta 0), reused 0 (delta 0), pack-reused 17038
# Receiving objects: 100% (17038/17038), 136.02 MiB | 24.63 MiB/s, done.
# /content/Scene-Classification-Dataset-Split

# %% [markdown]
# #### <b>(알아보기) 데이터셋 설명</b>
#
# * 본 PyTorch용 장면(scene) 데이터셋은 17,034개의 다양한 <b>자연 경치(scene)</b> 이미지로 구성되어 있습니다.
# * 총 6개의 클래스(class)로 구성됩니다.
#
# <pre>
# 클래스 0. 빌딩(buildings)
# 클래스 1. 숲(forests)
# 클래스 2. 빙하(glacier)
# 클래스 3. 산(mountains)
# 클래스 4. 바다(sea)
# 클래스 5. 거리(street)
# </pre>
#
# * 각 이미지는 공통적으로 64 X 64 크기를 가집니다.
# * 데이터셋 폴더 구성은 다음과 같습니다.
#
# <pre>
# Dataset/
#     train/
#         buildings/
#         forests/
#         glacier/
#         mountains/
#         sea/
#         streat/
#     val/
#         buildings/
#         forests/
#         glacier/
#         mountains/
#         sea/
#         streat/
# </pre>

# %% [markdown]
# #### <b>(알아보기) 클래스별 학습 이미지 개수 출력하기</b>
#
# * 클래스별 데이터의 개수를 계산합니다.
#     * os 라이브러리의 os.listdir()를 이용하여 이미지 폴더에 존재하는 파일 이름 목록을 얻을 수 있습니다.
#     * 클래스의 개수는 6개입니다.
# * 총 학습 데이터의 개수는 13,627개입니다.
#
# <pre>
# 클래스 0. 빌딩(buildings): 2,105개
# 클래스 1. 숲(forests): 2,205개
# 클래스 2. 빙하(glacier): 2,363개
# 클래스 3. 산(mountains): 2,438개
# 클래스 4. 바다(sea): 2,224개
# 클래스 5. 거리(street): 2,292개
# </pre>
#
# * 총 검증 데이터의 개수는 3,407개입니다.
#
# <pre>
# 클래스 0. 빌딩(buildings): 523개
# 클래스 1. 숲(forests): 540개
# 클래스 2. 빙하(glacier): 594개
# 클래스 3. 산(mountains): 599개
# 클래스 4. 바다(sea): 560개
# 클래스 5. 거리(street): 591개
# </pre>

# %%
import os


classes = ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']
train_path = 'train/'
val_path = 'val/'

print("[ 학습 데이터셋 ]")
for i in range(6):
    print(f'클래스 {i}의 개수: {len(os.listdir(train_path + classes[i]))}')

print("[ 검증 데이터셋 ]")
for i in range(6):
    print(f'클래스 {i}의 개수: {len(os.listdir(val_path + classes[i]))}')
# Out:
# [ 학습 데이터셋 ]
# 클래스 0의 개수: 2105
# 클래스 1의 개수: 2205
# 클래스 2의 개수: 2363
# 클래스 3의 개수: 2438
# 클래스 4의 개수: 2224
# 클래스 5의 개수: 2292
# [ 검증 데이터셋 ]
# 클래스 0의 개수: 523
# 클래스 1의 개수: 540
# 클래스 2의 개수: 594
# 클래스 3의 개수: 599
# 클래스 4의 개수: 560
# 클래스 5의 개수: 591

# %% [markdown]
# #### <b>(알아보기) 데이터셋 불러오기</b>
#
# * PyTorch의 <b>ImageFolder 라이브러리</b>를 이용하여 <b>자신만의 데이터셋</b>을 불러올 수 있습니다.
# * ImageFolder 라이브러리는 다음과 같이 <b>계층적인 폴더 구조</b>에서 데이터셋을 불러올 때 사용할 수 있습니다.
#     * 각 클래스명(class name)으로 된 폴더에 여러 장의 이미지가 들어가 있는 구조입니다.
#
# <pre>
# dataset/
#     class 0/
#         0.jpg
#         1.jpg
#         ...
#     class 1/
#         0.jpg
#         1.jpg
#         ...
#     ...
#     class 9/
#         0.jpg
#         1.jpg
#         ...
# </pre>
#
# * 기본적인 <b>데이터 증진(data augmentation)</b> 기법을 사용합니다.
#     * [RandomResizedCrop()](https://pytorch.org/vision/stable/transforms.html): 학습 시기에 랜덤으로 이미지의 일부를 잘라내어 특정 크기로 변형합니다.
#     * [RandomHorizontalFlip()](https://pytorch.org/vision/stable/transforms.html): 학습 시기에 랜덤으로 이미지를 좌우 반전합니다.
# * <b>정규화(normalization)를</b> 진행합니다.
#     * 일반적으로 많이 사용되는 ImageNet 데이터셋의 설정을 이용합니다.

# %%
import torch
from torchvision import datasets, transforms


device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # device object
print(device)

# 변형 Sequence
transforms_train = transforms.Compose([
    transforms.RandomResizedCrop((64, 64)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(train_path, transforms_train)
val_dataset = datasets.ImageFolder(val_path, transforms_val)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset))
print('Validation dataset size:', len(val_dataset))

class_names = train_dataset.classes
print('Class names:', class_names)
# Out:
# cuda
# Training dataset size: 13627
# Validation dataset size: 3407
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']

# %% [markdown]
# #### <b>(알아보기) 이미지 시각화하기</b>
#
# * PyTorch로 불러온 데이터(torch.Tensor 객체)를 시각화해 봅시다.
# * Google Colab에 출력하기 위해서 NumPy 형태로 변형한 뒤에 Matplotlib을 이용합니다.
#     * torch.Tensor는 (Channel, Height, Width) 형식을 가집니다.
#     * numpy 객체는 (Height, Width, Channel) 형식을 가집니다.

# %%
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# 화면에 출력되는 이미지 크기를 적절하게 조절하기
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 60
plt.rcParams.update({'font.size': 20})


def imshow(image, title):
    # torch.Tensor => numpy 변환하기
    image = image.numpy().transpose((1, 2, 0))
    # 이미지 정규화(normalization) 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)
    # 화면에 이미지 출력하기
    plt.imshow(image)
    plt.title(title)
    plt.show()


# 학습 데이터셋에서 하나의 배치를 불러와 보기
iterator = iter(train_dataloader)

# 현재 배치에 포함된 이미지를 출력하기
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs[:4])
imshow(out, title=[class_names[x] for x in classes[:4]])

# %% [markdown]
# ## <b>Problem 2. Convolution 연산 이해하기</b>
#
# * Convolution 연산의 동작 원리를 이해할 필요가 있습니다.
# * <b>[그림 예시]</b> 아래 그림에서는 stride가 1이고, padding이 0일 때의 Convolution 연산 예시를 보입니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <hr>
#
# * 입력 데이터의 높이: $height$
# * 입력 데이터의 너비: $width$
# * 필터의 높이: $filter\_height$
# * 필터의 너비: $filter\_width$
# * 스트라이드(stride): $stride$
# * 패딩 크기: $padding$
#
# <hr>
#
# * Convolution 연산 이후의 출력 차원은 다음과 같은 공식으로 계산할 수 있습니다. (나누기할 때 소수점 아래 버림)
#     * 출력 높이(output height) = $(height + 2 * padding - filter\\_height) / stride + 1$
#     * 출력 너비(output width) = $(width + 2 * padding - filter\\_width) / stride + 1$
#
# * <b>[문제]</b> 다음의 각 경우에 대하여 Convolution 연산을 수행한 뒤의 출력 차원을 쓰세요.
#     1. $height=32$, $width=32$, $filter\\_height=5$, $filter\\_width=5$, $stride=2$, $padding=2$일 때 → 16
#     2. $height=64$, $width=64$, $filter\\_height=3$, $filter\\_width=3$, $stride=1$, $padding=1$일 때 → 64
#     3. $height=16$, $width=16$, $filter\\_height=4$, $filter\\_width=4$, $stride=2$, $padding=1$일 때 → 8
#     4. $height=60$, $width=45$, $filter\\_height=8$, $filter\\_width=5$, $stride=3$, $padding=1$일 때 → 19, 15
#
# * (Hint) 다음과 같은 Python 코드를 사용하여 간단히 계산할 수 있습니다.
#
# <pre>
# height = 16
# width = 16
# filter_height = 4
# filter_width = 4
# stride = 2
# padding = 1
#
# output_height = (height + 2 * padding - filter_height) // stride + 1
# output_width = (width + 2 * padding - filter_width) // stride + 1
#
# print('출력 높이:', output_height, '출력 너비:', output_width)
# </pre>
#
# * 실행 결과 예시
#
# <pre>
# 출력 높이: 8 출력 너비: 8
# </pre>

# %%
height = 10
width = 10
filter_height = 4
filter_width = 4
stride = 1
padding = 0

output_height = (height + 2 * padding - filter_height) // stride + 1
output_width = (width + 2 * padding - filter_width) // stride + 1

print('출력 높이:', output_height, '출력 너비:', output_width)
# Out:
# 출력 높이: 7 출력 너비: 7

# %% [markdown]
# #### <b>(알아보기) Lenet 아키텍처 이해하기</b>
#
# * 기본적인 LeNet 아키텍처를 이해할 수 있습니다.
#     * Convolutional Neural Network를 최초로(1998년) 적용한 간단한 아키텍처입니다.
#     * Convolution 연산과 Pooling 연산이 사용됩니다.
# * <b>아래의 표</b>와 같은 아키텍처를 PyTorch로 구현한 것을 확인해 봅시다.
#     * 원본 논문과 완전히 동일하지는 않지만, 핵심 아이디어를 잘 표현한 아키텍처입니다.
#     * PyTorch에서는 모델에 별도로 Softmax 레이어를 두지 않고, 학습할 때 nn.CrossEntropyLoss()를 사용하는 것이 일반적입니다.

# %% [markdown]
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 20, kernel size: 5 X 5, stride: 1, zero padding: 0
# 3 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 4 | Convolution | # of kernel: 50, kernel size: 5 X 5, stride: 1, zero padding: 0
# 5 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 6 | Fully Connected | # of neuron: 500
# 7 | Activation | ReLU
# 8 | Fully Connected | # of neuron: 6
# 9 | Softmax | 6 classes

# %%
from torch import nn
import torch.nn.functional as F

class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        # → 차원(dimension): (3 x 64 x 64)
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=20, kernel_size=5, stride=1, padding=0)
        # → 차원(dimension): (20 x 60 x 60)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (20 x 30 x 30)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=50, kernel_size=5, stride=1, padding=0)
        # → 차원(dimension): (50 x 26 x 26)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (50 x 13 x 13)
        self.fc1 = nn.Linear(50 * 13 * 13, 500)
        # → 차원(dimension): (500)
        self.fc2 = nn.Linear(500, 6)
        # → 차원(dimension): (6)

    def forward(self, x):
        x = self.pool1(self.conv1(x))
        x = self.pool2(self.conv2(x))
        x = torch.flatten(x, 1) # 배치(batch)를 제외한 모든 차원 flatten하기
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
net = LeNet().to(device)
net
# Out:
# LeNet(
#   (conv1): Conv2d(3, 20, kernel_size=(5, 5), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(20, 50, kernel_size=(5, 5), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=8450, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=6, bias=True)
# )

# %% [markdown]
# #### <b>(알아보기) 학습 및 평가 함수 이해하기</b>
#
# * 별도의 학습(train) 함수와 평가(validate) 함수를 작성합니다.

# %%
def train(net, epoch, optimizer, criterion, train_dataloader, device='cuda:0'):
    print('[ Train epoch: %d ]' % epoch)
    net.train() # 모델을 학습 모드로 설정
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad() # 기울기(gradient) 초기화

        outputs = net(inputs) # 모델 입력하여 결과 계산
        loss = criterion(outputs, targets) # 손실(loss) 값 계산
        loss.backward() # 역전파를 통해 기울기(gradient) 계산

        optimizer.step() # 계산된 기울기를 이용해 모델 가중치 업데이트
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print('Train accuracy:{:.6f}'.format(100. * correct / total))
    print('Train average loss:{:.6f}'.format(train_loss / total))
    return (100. * correct / total, train_loss / total)


def validate(net, epoch, val_dataloader, device='cuda:0'):
    print('[ Validation epoch: %d ]' % epoch)
    net.eval() # 모델을 평가 모드로 설정
    val_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(val_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs) # 모델 입력하여 결과 계산
        val_loss += criterion(outputs, targets).item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    print('Accuracy:{:.6f}'.format(100. * correct / total))
    print('Average loss:{:.6f}'.format(val_loss / total))
    return (100. * correct / total, val_loss / total)

# %% [markdown]
# #### <b>(알아보기) LeNet 학습하기</b>
#
# * 앞서 정의한 LeNet 네트워크를 학습합니다.
# * 학습률(learning rate)을 수정해보면서 결과를 확인해 봅시다.
#     * 만약 학습률이 너무 크다면, 발산하여 손실(loss) 값이 NaN으로 나오며 학습이 안 될 수 있습니다.

# %%
import time
import torch.optim as optim


net = LeNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LeNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i + 1, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')
    print()

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 50.040361047919575
# Train average loss: 0.039815299739454135
# [ Validation epoch: 1 ]
# Accuarcy: 62.57704725565013
# Average loss: 0.030319085560623137
# Model saved! (time elapsed: 107.22462844848633)
#
# [ Train epoch: 1 ]
# Train accuarcy: 58.66294855800983
# Train average loss: 0.03366433540111051
# [ Validation epoch: 2 ]
# Accuarcy: 68.79953037863223
# Average loss: 0.02703376338738726
# Model saved! (time elapsed: 219.19900584220886)
#
# [ Train epoch: 2 ]
# Train accuarcy: 61.30476260365451
# Train average loss: 0.03178614196454017
# [ Validation epoch: 3 ]
# Accuarcy: 71.5585559142941
# Average loss: 0.02501983117035557
# Model saved! (time elapsed: 353.5327444076538)
#
# [ Train epoch: 3 ]
# Train accuarcy: 63.792470829969915
# Train average loss: 0.030288839531354233
# [ Validation epoch: 4 ]
# Accuarcy: 73.05547402406809
# Average loss: 0.023936323775620903
# Model saved! (time elapsed: 456.7878439426422)
#
# [ Train epoch: 4 ]
# Train accuarcy: 64.81984295883173
# Train average loss: 0.029342270876364547
# [ Validation epoch: 5 ]
# Accuarcy: 72.61520399178163
# Average loss: 0.023645804972462478
# Model saved! (time elapsed: 561.1875958442688)
#
# [ Train epoch: 5 ]
# Train accuarcy: 66.69846628017906
# Train average loss: 0.02827717071322411
# [ Validation epoch: 6 ]
# Accuarcy: 74.46433812738479
# Average loss: 0.023273157905475603
# Model saved! (time elapsed: 656.7733201980591)
#
# [ Train epoch: 6 ]
# Train accuarcy: 66.9479709400455
# Train average loss: 0.02800093274206796
# [ Validation epoch: 7 ]
# Accuarcy: 72.29233930143822
# Average loss: 0.024020309904155615
# Model saved! (time elapsed: 759.8596439361572)
#
# [ Train epoch: 7 ]
# Train accuarcy: 66.82321861011228
# Train average loss: 0.02786502699391144
# [ Validation epoch: 8 ]
# Accuarcy: 75.08071617258585
# Average loss: 0.022067128247377773
# Model saved! (time elapsed: 859.9200472831726)
#
# [ Train epoch: 8 ]
# Train accuarcy: 67.8579291113231
# Train average loss: 0.02694519750438748
# [ Validation epoch: 9 ]
# Accuarcy: 75.08071617258585
# Average loss: 0.02191048574510613
# Model saved! (time elapsed: 957.8989968299866)
#
# [ Train epoch: 9 ]
# Train accuarcy: 67.82857562192706
# Train average loss: 0.026923761861973587
# [ Validation epoch: 10 ]
# Accuarcy: 78.39741708247725
# Average loss: 0.020047489388583167
# Model saved! (time elapsed: 1058.7163078784943)
#
# [ Train epoch: 10 ]
# Train accuarcy: 69.30358846407867
# Train average loss: 0.026112949742323987
# [ Validation epoch: 11 ]
# Accuarcy: 75.13941884355738
# Average loss: 0.021835064490869454
# Model saved! (time elapsed: 1155.644607782364)
#
# [ Train epoch: 11 ]
# Train accuarcy: 69.23754311293754
# Train average loss: 0.02594764108457332
# [ Validation epoch: 12 ]
# Accuarcy: 74.72850014675667
# Average loss: 0.022264675421206734
# Model saved! (time elapsed: 1257.6066777706146)
#
# [ Train epoch: 12 ]
# Train accuarcy: 69.47237102810597
# Train average loss: 0.025816237304498824
# [ Validation epoch: 13 ]
# Accuarcy: 75.46228353390079
# Average loss: 0.021757591652457303
# Model saved! (time elapsed: 1357.7373566627502)
#
# [ Train epoch: 13 ]
# Train accuarcy: 70.22088500770529
# Train average loss: 0.02536289107294769
# [ Validation epoch: 14 ]
# Accuarcy: 77.92779571470501
# Average loss: 0.020653628624181856
# Model saved! (time elapsed: 1456.6079478263855)
#
# [ Train epoch: 14 ]
# Train accuarcy: 70.25757686945036
# Train average loss: 0.025394184475924148
# [ Validation epoch: 15 ]
# Accuarcy: 76.16671558555915
# Average loss: 0.02142604365879257
# Model saved! (time elapsed: 1556.1378934383392)
#
# [ Train epoch: 15 ]
# Train accuarcy: 71.42437807294343
# Train average loss: 0.02462923458529348
# [ Validation epoch: 16 ]
# Accuarcy: 76.92985030818902
# Average loss: 0.02075169703671405
# Model saved! (time elapsed: 1654.3654029369354)
#
# [ Train epoch: 16 ]
# Train accuarcy: 71.25559550891612
# Train average loss: 0.024742061609199045
# [ Validation epoch: 17 ]
# Accuarcy: 77.10595832110361
# Average loss: 0.020251280791884752
# Model saved! (time elapsed: 1755.072597026825)
#
# [ Train epoch: 17 ]
# Train accuarcy: 71.31430248770823
# Train average loss: 0.02438468371088825
# [ Validation epoch: 18 ]
# Accuarcy: 78.30936307601996
# Average loss: 0.019645757118137763
# Model saved! (time elapsed: 1853.0321996212006)
#
# [ Train epoch: 18 ]
# Train accuarcy: 71.16019666837896
# Train average loss: 0.02449565647790374
# [ Validation epoch: 19 ]
# Accuarcy: 76.84179630173173
# Average loss: 0.020936892980489348
# Model saved! (time elapsed: 1952.0646817684174)
#
# [ Train epoch: 19 ]
# Train accuarcy: 71.59316063697072
# Train average loss: 0.024172316322220284
# [ Validation epoch: 20 ]
# Accuarcy: 78.80833577927795
# Average loss: 0.019520796750135565
# Model saved! (time elapsed: 2052.224019050598)
#
# [ Train epoch: 20 ]
# Train accuarcy: 71.95274088207236
# Train average loss: 0.02404947659716862
# [ Validation epoch: 21 ]
# Accuarcy: 78.72028177282067
# Average loss: 0.019393657694158226
# Model saved! (time elapsed: 2151.8011722564697)
#
# [ Train epoch: 21 ]
# Train accuarcy: 72.2609525207309
# Train average loss: 0.02390760914450251
# [ Validation epoch: 22 ]
# Accuarcy: 76.40152626944526
# Average loss: 0.020961215874299926
# Model saved! (time elapsed: 2250.782769203186)
#
# [ Train epoch: 22 ]
# Train accuarcy: 72.0334629779115
# Train average loss: 0.024219495469654104
# [ Validation epoch: 23 ]
# Accuarcy: 78.57352509539184
# Average loss: 0.01914764516053397
# Model saved! (time elapsed: 2348.2105526924133)
#
# [ Train epoch: 23 ]
# Train accuarcy: 73.01680487267924
# Train average loss: 0.023150748359122123
# [ Validation epoch: 24 ]
# Accuarcy: 79.30730848253596
# Average loss: 0.019414249450047064
# Model saved! (time elapsed: 2446.555317878723)
#
# [ Train epoch: 24 ]
# Train accuarcy: 72.6572246275776
# Train average loss: 0.023285575100057604
# [ Validation epoch: 25 ]
# Accuarcy: 79.36601115350749
# Average loss: 0.018562402496388276
# Model saved! (time elapsed: 2546.5742795467377)
#
# [ Train epoch: 25 ]
# Train accuarcy: 73.34703162838483
# Train average loss: 0.022816277929418566
# [ Validation epoch: 26 ]
# Accuarcy: 78.74963310830643
# Average loss: 0.01969714780286991
# Model saved! (time elapsed: 2646.1724853515625)
#
# [ Train epoch: 26 ]
# Train accuarcy: 73.13421883026345
# Train average loss: 0.023082761419154475
# [ Validation epoch: 27 ]
# Accuarcy: 79.80628118579395
# Average loss: 0.019096076619705568
# Model saved! (time elapsed: 2747.7221751213074)
#
# [ Train epoch: 27 ]
# Train accuarcy: 73.25163278784765
# Train average loss: 0.023138889967586042
# [ Validation epoch: 28 ]
# Accuarcy: 78.95509245670678
# Average loss: 0.01942346470951509
# Model saved! (time elapsed: 2848.8857436180115)
#
# [ Train epoch: 28 ]
# Train accuarcy: 74.2349746826154
# Train average loss: 0.022290892099139186
# [ Validation epoch: 29 ]
# Accuarcy: 80.04109186968007
# Average loss: 0.01879907336653521
# Model saved! (time elapsed: 2948.451684951782)
#
# [ Train epoch: 29 ]
# Train accuarcy: 73.09752696851838
# Train average loss: 0.022675883608588018
# [ Validation epoch: 30 ]
# Accuarcy: 78.86703845024948
# Average loss: 0.019321365469461456
# Model saved! (time elapsed: 3046.2493245601654)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### <b>(알아보기) 혼동 행렬 시각화하기</b>
#
# * 참고: [Seaborn.heatmap 공식 문서](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
# * 각 클래스에 대하여 정확히 분류하는지 확인하기 위해 <b>혼동 행렬(confusion matrix)</b>을 생성할 수 있습니다.

# %%
# 네트워크에 데이터셋을 입력하여 혼동 행렬(confusion matrix)을 계산하는 함수
def get_confusion_matrix(net, num_classes, data_loader):
    net.eval() # 모델을 평가 모드로 설정
    confusion_matrix = torch.zeros(num_classes, num_classes, dtype=torch.int32)

    for batch_idx, (inputs, targets) in enumerate(data_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = net(inputs)
        _, predicted = outputs.max(1)

        for t, p in zip(targets.view(-1), predicted.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1

    return confusion_matrix

# %%
import pandas as pd
import seaborn as sns


net = LeNet()
net = net.to(device)

file_name = "./checkpoint/LeNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.6807, 0.9519, 0.6987, 0.8364, 0.7482, 0.8156])
# [ 전체 평균 정확도 ]
# tensor(0.7887)

# %% [markdown]
# ## <b>Problem 3. CustomLeNet 아키텍처 작성하기</b>
#
# * 다음과 같이 LeNet 아키텍처를 변경하여 CustomLeNet을 만들어 봅시다.
#     * 커널 크기와 커널의 개수를 증가시켰습니다. (파라미터 수 증가)
#     * Fully Connected 레이어의 차원을 증가시켰습니다. (파라미터 수 증가)
#
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 128, kernel size: 8 X 8, stride: 1, zero padding: 0
# 3 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 4 | Convolution | # of kernel: 256, kernel size: 8 X 8, stride: 1, zero padding: 0
# 5 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 6 | Convolution | # of kernel: 512, kernel size: 4 X 4, stride: 1, zero padding: 0
# 7 | Pooling | max pooling, kernel size: 2 X 2, stride: 2
# 8 | Fully Connected | # of neuron: 4096
# 9 | Activation | ReLU
# 10 | Fully Connected | # of neuron: 6
# 11 | Softmax | 6 classes

# %%
import torch.nn as nn
import torch.nn.functional as F

class CustomLeNet(nn.Module):
    def __init__(self):
        super(CustomLeNet, self).__init__()
        # → 차원(dimension): (3 x 64 x 64)

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=128,
                               kernel_size=8, stride=1, padding=0)
        # → 차원(dimension): (128 x 57 x 57)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (128 x 28 x 28)

        self.conv2 = nn.Conv2d(in_channels=128, out_channels=256,
                               kernel_size=8, stride=1, padding=0)
        # → 차원(dimension): (256 x 21 x 21)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (256 x 10 x 10)

        self.conv3 = nn.Conv2d(in_channels=256, out_channels=512,
                               kernel_size=4, stride=1, padding=0)
        # → 차원(dimension): (512 x 7 x 7)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        # → 차원(dimension): (512 x 3 x 3)

        self.fc = nn.Sequential(
            nn.Linear(512 * 3 * 3, 4096),
            nn.ReLU,
            nn.Linear(4096, 6)
        )


    def forward(self, x):
        x = self.pool1(self.conv1(x))
        x = self.pool2(self.conv2(x))
        x = self.pool3(self.conv3(x))
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

# %% [markdown]
# #### <b>(알아보기) CustomLeNet 평가하기</b>
#
# * 새롭게 작성한 CustomLeNet과 앞선 LeNet의 성능을 비교합니다.
#     * 파라미터가 증가한 만큼 성능 향상이 있는지 확인해 봅시다.
# * 아래 코드를 실행하여 학습 및 성능 평가를 진행할 수 있습니다.

# %%
import time
import torch.optim as optim


net = CustomLeNet()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "CustomLeNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i + 1, optimizer, criterion, train_dataloader, device='cuda') # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader, device='cuda') # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 1 ]
# Train accuracy:48.264475
# Train average loss:0.040618
# [ Validation epoch: 1 ]
# Accuracy:61.021426
# Average loss:0.031753
# Model saved! (time elapsed: 25.987773656845093)
# [ Train epoch: 2 ]
# Train accuracy:56.549497
# Train average loss:0.035089
# [ Validation epoch: 2 ]
# Accuracy:65.688289
# Average loss:0.028652
# Model saved! (time elapsed: 49.36666798591614)
# [ Train epoch: 3 ]
# Train accuracy:58.949145
# Train average loss:0.033500
# [ Validation epoch: 3 ]
# Accuracy:65.512181
# Average loss:0.028502
# Model saved! (time elapsed: 73.20695781707764)
# [ Train epoch: 4 ]
# Train accuracy:60.614956
# Train average loss:0.032163
# [ Validation epoch: 4 ]
# Accuracy:69.269152
# Average loss:0.026118
# Model saved! (time elapsed: 96.87786078453064)
# [ Train epoch: 5 ]
# Train accuracy:61.620313
# Train average loss:0.031547
# [ Validation epoch: 5 ]
# Accuracy:66.011154
# Average loss:0.027668
# Model saved! (time elapsed: 120.25040316581726)
# [ Train epoch: 6 ]
# Train accuracy:62.515594
# Train average loss:0.030891
# [ Validation epoch: 6 ]
# Accuracy:71.206340
# Average loss:0.025441
# Model saved! (time elapsed: 143.93901658058167)
# [ Train epoch: 7 ]
# Train accuracy:64.041975
# Train average loss:0.029745
# [ Validation epoch: 7 ]
# Accuracy:72.761961
# Average loss:0.023950
# Model saved! (time elapsed: 167.61847257614136)
# [ Train epoch: 8 ]
# Train accuracy:65.076686
# Train average loss:0.029104
# [ Validation epoch: 8 ]
# Accuracy:73.319636
# Average loss:0.023942
# Model saved! (time elapsed: 191.8394546508789)
# [ Train epoch: 9 ]
# Train accuracy:65.208777
# Train average loss:0.028858
# [ Validation epoch: 9 ]
# Accuracy:73.583798
# Average loss:0.023135
# Model saved! (time elapsed: 216.3864061832428)
# [ Train epoch: 10 ]
# Train accuracy:65.663756
# Train average loss:0.028651
# [ Validation epoch: 10 ]
# Accuracy:70.413854
# Average loss:0.024674
# Model saved! (time elapsed: 240.71189713478088)
# [ Train epoch: 11 ]
# Train accuracy:66.360901
# Train average loss:0.028307
# [ Validation epoch: 11 ]
# Accuracy:69.181098
# Average loss:0.025524
# Model saved! (time elapsed: 264.3092966079712)
# [ Train epoch: 12 ]
# Train accuracy:66.654436
# Train average loss:0.027997
# [ Validation epoch: 12 ]
# Accuracy:73.671852
# Average loss:0.022386
# Model saved! (time elapsed: 288.2290070056915)
# [ Train epoch: 13 ]
# Train accuracy:67.483672
# Train average loss:0.027733
# [ Validation epoch: 13 ]
# Accuracy:74.141473
# Average loss:0.023119
# Model saved! (time elapsed: 312.22428011894226)
# [ Train epoch: 14 ]
# Train accuracy:67.028693
# Train average loss:0.027469
# [ Validation epoch: 14 ]
# Accuracy:71.617259
# Average loss:0.024771
# Model saved! (time elapsed: 336.2727026939392)
# [ Train epoch: 15 ]
# Train accuracy:67.843252
# Train average loss:0.027030
# [ Validation epoch: 15 ]
# Accuracy:74.875257
# Average loss:0.022520
# Model saved! (time elapsed: 360.18185925483704)
# [ Train epoch: 16 ]
# Train accuracy:67.711162
# Train average loss:0.027040
# [ Validation epoch: 16 ]
# Accuracy:73.290285
# Average loss:0.024438
# Model saved! (time elapsed: 384.4560546875)
# [ Train epoch: 17 ]
# Train accuracy:68.569751
# Train average loss:0.026331
# [ Validation epoch: 17 ]
# Accuracy:75.315527
# Average loss:0.022543
# Model saved! (time elapsed: 408.9842975139618)
# [ Train epoch: 18 ]
# Train accuracy:68.268878
# Train average loss:0.026556
# [ Validation epoch: 18 ]
# Accuracy:73.965365
# Average loss:0.023439
# Model saved! (time elapsed: 432.74509954452515)
# [ Train epoch: 19 ]
# Train accuracy:68.789902
# Train average loss:0.025987
# [ Validation epoch: 19 ]
# Accuracy:75.579689
# Average loss:0.022176
# Model saved! (time elapsed: 456.65010261535645)
# [ Train epoch: 20 ]
# Train accuracy:68.650473
# Train average loss:0.026448
# [ Validation epoch: 20 ]
# Accuracy:77.370120
# Average loss:0.020504
# Model saved! (time elapsed: 480.4197723865509)
# [ Train epoch: 21 ]
# Train accuracy:69.567770
# Train average loss:0.025841
# [ Validation epoch: 21 ]
# Accuracy:75.697094
# Average loss:0.021370
# Model saved! (time elapsed: 504.1867024898529)
# [ Train epoch: 22 ]
# Train accuracy:69.721876
# Train average loss:0.025612
# [ Validation epoch: 22 ]
# Accuracy:76.401526
# Average loss:0.020720
# Model saved! (time elapsed: 528.17724442482)
# [ Train epoch: 23 ]
# Train accuracy:70.455713
# Train average loss:0.025210
# [ Validation epoch: 23 ]
# Accuracy:74.611095
# Average loss:0.022445
# Model saved! (time elapsed: 552.3999032974243)
# [ Train epoch: 24 ]
# Train accuracy:69.927350
# Train average loss:0.025290
# [ Validation epoch: 24 ]
# Accuracy:76.929850
# Average loss:0.020825
# Model saved! (time elapsed: 579.0343990325928)
# [ Train epoch: 25 ]
# Train accuracy:70.374991
# Train average loss:0.025047
# [ Validation epoch: 25 ]
# Accuracy:77.105958
# Average loss:0.020446
# Model saved! (time elapsed: 603.9534821510315)
# [ Train epoch: 26 ]
# Train accuracy:69.927350
# Train average loss:0.025061
# [ Validation epoch: 26 ]
# Accuracy:73.671852
# Average loss:0.023949
# Model saved! (time elapsed: 628.5001173019409)
# [ Train epoch: 27 ]
# Train accuracy:70.499743
# Train average loss:0.025068
# [ Validation epoch: 27 ]
# Accuracy:76.665688
# Average loss:0.021182
# Model saved! (time elapsed: 652.6298644542694)
# [ Train epoch: 28 ]
# Train accuracy:70.653849
# Train average loss:0.024765
# [ Validation epoch: 28 ]
# Accuracy:78.397417
# Average loss:0.019656
# Model saved! (time elapsed: 676.5058941841125)
# [ Train epoch: 29 ]
# Train accuracy:70.874000
# Train average loss:0.024489
# [ Validation epoch: 29 ]
# Accuracy:78.015850
# Average loss:0.019715
# Model saved! (time elapsed: 700.5903632640839)
# [ Train epoch: 30 ]
# Train accuracy:70.969399
# Train average loss:0.024499
# [ Validation epoch: 30 ]
# Accuracy:77.546228
# Average loss:0.020268
# Model saved! (time elapsed: 724.5656526088715)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = CustomLeNet()
net = net.to(device)

file_name = "./checkpoint/CustomLeNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())

# %% [markdown]
# ## <b>Problem 4. AlexNet 아키텍처 작성하기</b>
#
# * AlexNet은 CNN 기반의 분류 모델의 우수성을 전 세계에 알린 논문([NIPS 2012](https://papers.nips.cc/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf))입니다.
#     * ImageNet 분류 대회(ILSVRC 2012)에서 압도적인 성능으로 우승(1위)을 차지했습니다.
#
# <hr>
#
# * LRN (Local Response Normalization)을 활용합니다.
#     * PyTorch에서 [nn.LocalResponseNorm()](https://pytorch.org/docs/stable/generated/torch.nn.LocalResponseNorm.html)을 이용해 구현할 수 있습니다.
#     * Local Response Normalization은 입력과 출력의 차원이 동일한 레이어입니다.
# * Dropout을 활용합니다.
#     * PyTorch에서 [nn.Dropout()](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)을 이용해 구현할 수 있습니다.
# * ReLU를 적극적으로 활용합니다.
#     * PyTorch에서 [nn.ReLU()](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html)를 이용해 구현할 수 있습니다.
#
# <hr>
#
# * <b>아래의 표</b>와 같은 아키텍처를 PyTorch로 구현해 봅시다.
#     * 원본 논문에서 제안한 것과 완전히 동일한 아키텍처는 아니지만, 핵심 아이디어를 잘 포함하고 있습니다.
#
# Layer | Type | Specification
# :-: | :-: | ---
# 1 | Input | image size: 3 X 64 X 64
# 2 | Convolution | # of kernel: 96, kernel size: 5 X 5, stride: 1, zero padding: 2
# 3 | Activation | ReLU
# 4 | Normalization | LRN (Local Response Normalization), size: 5
# 5 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 6 | Convolution | # of kernel: 256, kernel size: 5 X 5, stride: 1, zero padding: 2
# 7 | Activation | ReLU
# 8 | Normalization | LRN (Local Response Normalization), size: 5
# 9 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 10 | Convolution | # of kernel: 384, kernel size: 3 X 3, stride: 1, zero padding: 1
# 11 | Activation | ReLU
# 12 | Convolution | # of kernel: 384, kernel size: 3 X 3, stride: 1, zero padding: 1
# 13 | Activation | ReLU
# 14 | Convolution | # of kernel: 256, kernel size: 3 X 3, stride: 1, zero padding: 1
# 15 | Activation | ReLU
# 16 | Pooling | max pooling, kernel size: 3 X 3, stride: 2
# 17 | Fully Connected | # of neuron: 4096
# 18 | Activation | ReLU
# 19 | Dropout | Probability: 0.5
# 20 | Fully Connected | # of neuron: 6
# 21 | Dropout | Probability: 0.5
# 22 | Softmax | 6 classes
#
# * 표와 동일하게 정상적으로 구현했다면, <b>83~85%가량의 정확도</b>를 얻을 수 있습니다.

# %%
height = 64
filter_height = 5
stride = 1
padding = 2

output_height = (height + 2 * padding - filter_height) // stride + 1

print('출력 높이:', output_height)
# Out:
# 출력 높이: 64

# %%
from torch import nn
import torch.nn.functional as F

class AlexNet(nn.Module):
    def __init__(self):
        super(AlexNet, self).__init__()
        # → 차원(dimension): (3 x 64 x 64)

        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=96,
                      kernel_size=5, stride=1, padding=2),
            # → 차원(dimension): (96 x 64 x 64)
            nn.LocalResponseNorm(size=5),
            # → 차원(dimension): (96 x 64 x 64)
            nn.MaxPool2d(kernel_size=3, stride=2)
            # → 차원(dimension): (96 x 31 x 31)
        )

        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=96, out_channels=256,
                      kernel_size=5, stride=1, padding=2),
            # → 차원(dimension): (256 x 31 x 31)
            nn.LocalResponseNorm(size=5),
            # → 차원(dimension): (256 x 31 x 31)
            nn.MaxPool2d(kernel_size=3, stride=2)
            # → 차원(dimension): (256 x 15 x 15)
        )

        self.layer3 = nn.Sequential(
            nn.Conv2d(in_channels=256, out_channels=384,
                      kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            # → 차원(dimension): (384 x 15 x 15)
            nn.Conv2d(in_channels=384, out_channels=384,
                      kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            # → 차원(dimension): (384 x 15 x 15)
            nn.Conv2d(in_channels=384, out_channels=256,
                      kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            # → 차원(dimension): (256 x 15 x 15)
            nn.MaxPool2d(kernel_size=3, stride=2)
            # → 차원(dimension): (256 x 7 x 7)
        )

        self.fc = nn.Sequential(
            nn.Linear(256 * 7 * 7, 4096),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(4096, 6),
            nn.Dropout(0.5)
        )

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.relu(self.layer3(x))
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

# %%
net = AlexNet()
net = net.to(device)

for x, _ in train_dataloader:
    x = x.to(device)
    print(x.shape)
    x = net.layer1(x)
    print(x.shape)
    x = net.layer2(x)
    print(x.shape)
    x = net.layer3(x)
    print(x.shape)
    x = torch.flatten(x, 1)
    x = net.fc(x)
    print(x.shape)


    break
# Out:
# torch.Size([32, 3, 64, 64])
# torch.Size([32, 96, 31, 31])
# torch.Size([32, 256, 15, 15])
# torch.Size([32, 256, 7, 7])
# torch.Size([32, 6])

# %% [markdown]
# #### <b>(알아보기) AlexNet 평가하기</b>
#
# * 아래 코드를 실행하여 학습 및 성능 평가를 진행할 수 있습니다.
# * 83~85%가량의 정확도가 나오지 않는다면, 표와 동일하게 AlexNet 코드를 다시 작성했는지 확인해 주세요.

# %%
import time
import torch.optim as optim


net = AlexNet()
net = net.to(device)

epoch = 10
learning_rate = 0.002
file_name = "AlexNet.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuracy:35.026051
# Train average loss:0.048116
# [ Validation epoch: 1 ]
# Accuracy:60.610508
# Average loss:0.034937
# Model saved! (time elapsed: 35.208805084228516)
# [ Train epoch: 1 ]
# Train accuracy:40.632568
# Train average loss:0.044223
# [ Validation epoch: 2 ]
# Accuracy:66.715586
# Average loss:0.030603
# Model saved! (time elapsed: 69.6507773399353)
# [ Train epoch: 2 ]
# Train accuracy:43.920159
# Train average loss:0.041754
# [ Validation epoch: 3 ]
# Accuracy:67.654828
# Average loss:0.029287
# Model saved! (time elapsed: 103.43583750724792)
# [ Train epoch: 3 ]
# Train accuracy:45.879504
# Train average loss:0.040446
# [ Validation epoch: 4 ]
# Accuracy:73.877311
# Average loss:0.025142
# Model saved! (time elapsed: 136.83633542060852)
# [ Train epoch: 4 ]
# Train accuracy:46.745432
# Train average loss:0.039444
# [ Validation epoch: 5 ]
# Accuracy:76.695040
# Average loss:0.023040
# Model saved! (time elapsed: 169.94435501098633)
# [ Train epoch: 5 ]
# Train accuracy:47.207749
# Train average loss:0.038677
# [ Validation epoch: 6 ]
# Accuracy:69.093044
# Average loss:0.028535
# Model saved! (time elapsed: 204.13265538215637)
# [ Train epoch: 6 ]
# Train accuracy:48.191091
# Train average loss:0.037960
# [ Validation epoch: 7 ]
# Accuracy:76.636337
# Average loss:0.022614
# Model saved! (time elapsed: 237.18206906318665)
# [ Train epoch: 7 ]
# Train accuracy:48.814853
# Train average loss:0.037482
# [ Validation epoch: 8 ]
# Accuracy:78.368066
# Average loss:0.020433
# Model saved! (time elapsed: 270.7419455051422)
# [ Train epoch: 8 ]
# Train accuracy:49.328539
# Train average loss:0.037093
# [ Validation epoch: 9 ]
# Accuracy:77.604931
# Average loss:0.022056
# Model saved! (time elapsed: 304.5140016078949)
# [ Train epoch: 9 ]
# Train accuracy:49.644089
# Train average loss:0.036431
# [ Validation epoch: 10 ]
# Accuracy:79.072498
# Average loss:0.018823
# Model saved! (time elapsed: 337.98348355293274)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = AlexNet()
net = net.to(device)

file_name = "./checkpoint/AlexNet.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.7859, 0.9593, 0.7778, 0.7763, 0.7911, 0.6684])
# [ 전체 평균 정확도 ]
# tensor(0.7907)

# %% [markdown]
# #### <b>(알아보기) LightResNet 아키텍처 살펴보기</b>
#
# * [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385) 논문에서 제안된 가벼운 ResNet을 PyTorch로 구현한 것은 다음과 같습니다.
#     * 원본 논문에서는 CIFAR-10을 위하여 해당 아키텍처를 제안했습니다.
# * 레이어의 깊이에 따라 다양한 버전이 있습니다.
#     * 다양한 버전: 20 레이어, 32 레이어, 44 레이어, 56 레이어, 110 레이어
#     * 일반적으로 더 깊은 레이어로 구성된 ResNet이 더 높은 정확도를 보입니다.

# %%
# ResNet을 위한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (stride 값이 2라면, 너비와 높이가 절반으로 감소)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (stride 값이 1이므로, 너비와 높이가 유지)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, padding=0, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# LightResNet 클래스 정의
class LightResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=6):
        super(LightResNet, self).__init__()
        self.in_planes = 16

        # 16개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        # 첫 레이어를 제외하고는 너비와 높이를 줄이기 위해 stride를 2로 설정
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.linear = nn.Linear(64, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1) # 첫째 블록만 너비와 높이 감소
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1) # 배치(batch)를 제외한 모든 차원 flatten하기
        out = self.linear(out)
        return out


def LightResNet20():
    return LightResNet(BasicBlock, [3, 3, 3])


def LightResNet32():
    return LightResNet(BasicBlock, [5, 5, 5])


def LightResNet44():
    return LightResNet(BasicBlock, [7, 7, 7])


def LightResNet56():
    return LightResNet(BasicBlock, [9, 9, 9])


def LightResNet110():
    return LightResNet(BasicBlock, [18, 18, 18])

# %% [markdown]
# #### <b>(알아보기) LightResNet-20 학습하기</b>
#
# * PyTorch로 구현된 LightResNet-20 모델을 학습해 봅시다.

# %%
import time
import torch.optim as optim


net = LightResNet110()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "LightResNet10.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i + 1, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuracy:45.387833
# Train average loss:0.041997
# [ Validation epoch: 1 ]
# Accuracy:61.872615
# Average loss:0.031140
# Model saved! (time elapsed: 67.16540050506592)
# [ Train epoch: 1 ]
# Train accuracy:56.872386
# Train average loss:0.033562
# [ Validation epoch: 2 ]
# Accuracy:63.369533
# Average loss:0.029879
# Model saved! (time elapsed: 134.7275252342224)
# [ Train epoch: 2 ]
# Train accuracy:62.324796
# Train average loss:0.030425
# [ Validation epoch: 3 ]
# Accuracy:67.860288
# Average loss:0.026659
# Model saved! (time elapsed: 203.7217893600464)
# [ Train epoch: 3 ]
# Train accuracy:66.698466
# Train average loss:0.027560
# [ Validation epoch: 4 ]
# Accuracy:73.055474
# Average loss:0.023450
# Model saved! (time elapsed: 273.5498938560486)
# [ Train epoch: 4 ]
# Train accuracy:68.063404
# Train average loss:0.026318
# [ Validation epoch: 5 ]
# Accuracy:74.493689
# Average loss:0.022358
# Model saved! (time elapsed: 344.96849727630615)
# [ Train epoch: 5 ]
# Train accuracy:70.558450
# Train average loss:0.024782
# [ Validation epoch: 6 ]
# Accuracy:78.456120
# Average loss:0.019068
# Model saved! (time elapsed: 414.0310297012329)
# [ Train epoch: 6 ]
# Train accuracy:71.585822
# Train average loss:0.023688
# [ Validation epoch: 7 ]
# Accuracy:78.837687
# Average loss:0.018688
# Model saved! (time elapsed: 485.07057547569275)
# [ Train epoch: 7 ]
# Train accuracy:71.563807
# Train average loss:0.023404
# [ Validation epoch: 8 ]
# Accuracy:76.929850
# Average loss:0.019992
# Model saved! (time elapsed: 554.3316326141357)
# [ Train epoch: 8 ]
# Train accuracy:74.403757
# Train average loss:0.021991
# [ Validation epoch: 9 ]
# Accuracy:75.638392
# Average loss:0.019980
# Model saved! (time elapsed: 624.0393714904785)
# [ Train epoch: 9 ]
# Train accuracy:74.286343
# Train average loss:0.021716
# [ Validation epoch: 10 ]
# Accuracy:81.743469
# Average loss:0.016100
# Model saved! (time elapsed: 696.193008184433)
# [ Train epoch: 10 ]
# Train accuracy:74.888090
# Train average loss:0.021145
# [ Validation epoch: 11 ]
# Accuracy:80.628119
# Average loss:0.016266
# Model saved! (time elapsed: 768.1204741001129)
# [ Train epoch: 11 ]
# Train accuracy:75.438468
# Train average loss:0.020792
# [ Validation epoch: 12 ]
# Accuracy:80.158497
# Average loss:0.017095
# Model saved! (time elapsed: 843.0475361347198)
# [ Train epoch: 12 ]
# Train accuracy:76.348426
# Train average loss:0.020251
# [ Validation epoch: 13 ]
# Accuracy:73.143528
# Average loss:0.022185
# Model saved! (time elapsed: 913.8585965633392)
# [ Train epoch: 13 ]
# Train accuracy:76.487855
# Train average loss:0.019910
# [ Validation epoch: 14 ]
# Accuracy:82.829469
# Average loss:0.015256
# Model saved! (time elapsed: 985.1142830848694)
# [ Train epoch: 14 ]
# Train accuracy:77.500550
# Train average loss:0.019128
# [ Validation epoch: 15 ]
# Accuracy:83.240387
# Average loss:0.014846
# Model saved! (time elapsed: 1056.7889957427979)
# [ Train epoch: 15 ]
# Train accuracy:77.684010
# Train average loss:0.018823
# [ Validation epoch: 16 ]
# Accuracy:83.563252
# Average loss:0.014151
# Model saved! (time elapsed: 1129.46666097641)
# [ Train epoch: 16 ]
# Train accuracy:79.070962
# Train average loss:0.018236
# [ Validation epoch: 17 ]
# Accuracy:82.389199
# Average loss:0.014850
# Model saved! (time elapsed: 1199.956592798233)
# [ Train epoch: 17 ]
# Train accuracy:77.661995
# Train average loss:0.018796
# [ Validation epoch: 18 ]
# Accuracy:83.944819
# Average loss:0.014413
# Model saved! (time elapsed: 1270.3477239608765)
# [ Train epoch: 18 ]
# Train accuracy:79.159023
# Train average loss:0.017772
# [ Validation epoch: 19 ]
# Accuracy:82.066334
# Average loss:0.016413
# Model saved! (time elapsed: 1340.1763186454773)
# [ Train epoch: 19 ]
# Train accuracy:79.210391
# Train average loss:0.017760
# [ Validation epoch: 20 ]
# Accuracy:83.240387
# Average loss:0.014490
# Model saved! (time elapsed: 1411.1274135112762)
# [ Train epoch: 20 ]
# Train accuracy:79.298452
# Train average loss:0.017597
# [ Validation epoch: 21 ]
# Accuracy:84.267684
# Average loss:0.014207
# Model saved! (time elapsed: 1480.7031152248383)
# [ Train epoch: 21 ]
# Train accuracy:79.614002
# Train average loss:0.017377
# [ Validation epoch: 22 ]
# Accuracy:84.032873
# Average loss:0.014542
# Model saved! (time elapsed: 1551.2712054252625)
# [ Train epoch: 22 ]
# Train accuracy:80.567990
# Train average loss:0.016776
# [ Validation epoch: 23 ]
# Accuracy:84.003522
# Average loss:0.013853
# Model saved! (time elapsed: 1624.2004179954529)
# [ Train epoch: 23 ]
# Train accuracy:79.804799
# Train average loss:0.016793
# [ Validation epoch: 24 ]
# Accuracy:84.796008
# Average loss:0.013525
# Model saved! (time elapsed: 1697.642230272293)
# [ Train epoch: 24 ]
# Train accuracy:80.303809
# Train average loss:0.016550
# [ Validation epoch: 25 ]
# Accuracy:84.326387
# Average loss:0.013888
# Model saved! (time elapsed: 1768.315804719925)
# [ Train epoch: 25 ]
# Train accuracy:80.751449
# Train average loss:0.016475
# [ Validation epoch: 26 ]
# Accuracy:84.032873
# Average loss:0.014607
# Model saved! (time elapsed: 1838.6692419052124)
# [ Train epoch: 26 ]
# Train accuracy:80.479930
# Train average loss:0.016509
# [ Validation epoch: 27 ]
# Accuracy:84.355738
# Average loss:0.014202
# Model saved! (time elapsed: 1909.9022765159607)
# [ Train epoch: 27 ]
# Train accuracy:81.074338
# Train average loss:0.016064
# [ Validation epoch: 28 ]
# Accuracy:85.089522
# Average loss:0.014592
# Model saved! (time elapsed: 1979.449829339981)
# [ Train epoch: 28 ]
# Train accuracy:81.455933
# Train average loss:0.015995
# [ Validation epoch: 29 ]
# Accuracy:84.854711
# Average loss:0.013515
# Model saved! (time elapsed: 2050.23046875)
# [ Train epoch: 29 ]
# Train accuracy:81.441256
# Train average loss:0.015856
# [ Validation epoch: 30 ]
# Accuracy:84.003522
# Average loss:0.014100
# Model saved! (time elapsed: 2119.759684085846)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = LightResNet20()
net = net.to(device)

file_name = "./checkpoint/LightResNet20.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.8528, 0.9574, 0.7727, 0.8097, 0.9429, 0.8545])
# [ 전체 평균 정확도 ]
# tensor(0.8629)

# %% [markdown]
# ## <b>Problem 5. 다양한 레이어 깊이에 따라 LightResNet 학습하기</b>
#
# * Residual Block을 사용하는 경우 깊이가 깊어져도 좋은 성능을 내는 경향이 있습니다.
# * 다음의 LightResNet 모델들에 대하여 각각 학습을 진행한 뒤에, 검증 정확도(validation accuracy)를 쓰세요.
#     * LightResNet32: {답을 쓰세요.}
#     * LightResNet56: {답을 쓰세요.}
#     * LightResNet110: {답을 쓰세요.}
# * 레이어가 깊어짐에 따라서 성능이 좋아지나요? {답을 쓰세요.}
#     * 그 이유는: {답을 쓰세요.}

# %% [markdown]
# #### <b>(알아보기) ResNet 아키텍처 살펴보기</b>
#
# * [ResNet (2016 CVPR)](https://arxiv.org/abs/1512.03385) 논문에서 제안된 기본적인 ResNet의 핵심 아이디어를 PyTorch로 구현한 것은 다음과 같습니다.
#     * LightResNet에 비하여 <b>커널의 개수(number of kernels)가 많은</b> 것을 확인할 수 있습니다.
#     * 따라서 ImageNet과 같은 큰 규모의 데이터셋에 대해서 사용하기에 적합합니다.
# * (참고) [PyTorch 공식 ResNet 소스 코드](https://github.com/pytorch/vision/blob/master/torchvision/models/resnet.py)

# %%
# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=6):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        # 첫 레이어를 제외하고는 너비와 높이를 줄이기 위해 stride를 2로 설정
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1) # 첫째 블록만 너비와 높이 감소
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1) # 배치(batch)를 제외한 모든 차원 flatten하기
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

# %% [markdown]
# #### <b>(알아보기) ResNet-18 학습하기</b>
#
# * PyTorch로 구현된 ResNet-18 모델을 학습해 봅시다.

# %%
import time
import torch.optim as optim


net = ResNet18()
net = net.to(device)

epoch = 30
learning_rate = 0.002
file_name = "ResNet18.pt"

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i, optimizer, criterion, train_dataloader) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader) # 검증(validation)

    # 학습된 모델 저장하기
    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print(f'Model saved! (time elapsed: {time.time() - start_time})')

    # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
    train_result.append((train_acc, train_loss))
    val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 0 ]
# Train accuarcy: 54.634182138401705
# Train average loss: 0.03552350132220593
# [ Validation epoch: 1 ]
# Accuarcy: 64.04461402993836
# Average loss: 0.030625102927267008
# Model saved! (time elapsed: 56.392067432403564)
# [ Train epoch: 1 ]
# Train accuarcy: 66.28017905628532
# Train average loss: 0.027683555574666258
# [ Validation epoch: 2 ]
# Accuarcy: 76.22541825653067
# Average loss: 0.020909708783813402
# Model saved! (time elapsed: 112.09643793106079)
# [ Train epoch: 2 ]
# Train accuarcy: 70.65384897629706
# Train average loss: 0.024552799536580516
# [ Validation epoch: 3 ]
# Accuarcy: 75.72644555327267
# Average loss: 0.020803920747529105
# Model saved! (time elapsed: 168.0892436504364)
# [ Train epoch: 3 ]
# Train accuarcy: 73.06083510677331
# Train average loss: 0.022823793206008802
# [ Validation epoch: 4 ]
# Accuarcy: 75.2861755209862
# Average loss: 0.020782165577028867
# Model saved! (time elapsed: 224.10530710220337)
# [ Train epoch: 4 ]
# Train accuarcy: 75.04953401335584
# Train average loss: 0.02116022261676045
# [ Validation epoch: 5 ]
# Accuarcy: 80.33460522453771
# Average loss: 0.016757638259545637
# Model saved! (time elapsed: 280.1415412425995)
# [ Train epoch: 5 ]
# Train accuarcy: 76.37044103617818
# Train average loss: 0.01991496870949358
# [ Validation epoch: 6 ]
# Accuarcy: 81.5086586439683
# Average loss: 0.015801148935780693
# Model saved! (time elapsed: 336.057856798172)
# [ Train epoch: 6 ]
# Train accuarcy: 76.81074337711895
# Train average loss: 0.019498130532819895
# [ Validation epoch: 7 ]
# Accuarcy: 81.44995597299678
# Average loss: 0.015548953277504196
# Model saved! (time elapsed: 392.00325560569763)
# [ Train epoch: 7 ]
# Train accuarcy: 77.7940852718867
# Train average loss: 0.018866681710127262
# [ Validation epoch: 8 ]
# Accuarcy: 84.17963017317288
# Average loss: 0.013664885371319878
# Model saved! (time elapsed: 448.02228832244873)
# [ Train epoch: 8 ]
# Train accuarcy: 79.0416085712189
# Train average loss: 0.017912666459264467
# [ Validation epoch: 9 ]
# Accuarcy: 85.08952157323158
# Average loss: 0.013463371545120107
# Model saved! (time elapsed: 504.14816403388977)
# [ Train epoch: 9 ]
# Train accuarcy: 79.08563880531298
# Train average loss: 0.0176577540355776
# [ Validation epoch: 10 ]
# Accuarcy: 83.09363076019959
# Average loss: 0.015103666531154407
# Model saved! (time elapsed: 560.1805219650269)
# [ Train epoch: 10 ]
# Train accuarcy: 80.3918690834373
# Train average loss: 0.01709865421382611
# [ Validation epoch: 11 ]
# Accuarcy: 82.24244203111242
# Average loss: 0.015596012194239922
# Model saved! (time elapsed: 616.2508070468903)
# [ Train epoch: 11 ]
# Train accuarcy: 80.94224700961327
# Train average loss: 0.01624337270765143
# [ Validation epoch: 12 ]
# Accuarcy: 85.55914294100381
# Average loss: 0.012451799748788525
# Model saved! (time elapsed: 672.3249988555908)
# [ Train epoch: 12 ]
# Train accuarcy: 81.61003889337346
# Train average loss: 0.015776265370195816
# [ Validation epoch: 13 ]
# Accuarcy: 85.91135896683299
# Average loss: 0.012401989475001958
# Model saved! (time elapsed: 728.4691355228424)
# [ Train epoch: 13 ]
# Train accuarcy: 81.30182725471491
# Train average loss: 0.015962627105162816
# [ Validation epoch: 14 ]
# Accuarcy: 86.58643968300558
# Average loss: 0.012299993589612302
# Model saved! (time elapsed: 784.5571179389954)
# [ Train epoch: 14 ]
# Train accuarcy: 81.925588904381
# Train average loss: 0.015660236149407397
# [ Validation epoch: 15 ]
# Accuarcy: 83.29909010859994
# Average loss: 0.01429344191469333
# Model saved! (time elapsed: 840.6422958374023)
# [ Train epoch: 15 ]
# Train accuarcy: 82.18243193659646
# Train average loss: 0.015174747478929577
# [ Validation epoch: 16 ]
# Accuarcy: 85.76460228940417
# Average loss: 0.012752274200560796
# Model saved! (time elapsed: 896.5983777046204)
# [ Train epoch: 16 ]
# Train accuarcy: 82.51265869230205
# Train average loss: 0.014840699627874113
# [ Validation epoch: 17 ]
# Accuarcy: 84.35573818608746
# Average loss: 0.0133746397007166
# Model saved! (time elapsed: 952.5179381370544)
# [ Train epoch: 17 ]
# Train accuarcy: 83.03368312908196
# Train average loss: 0.014693979498942373
# [ Validation epoch: 18 ]
# Accuarcy: 87.17346639272087
# Average loss: 0.01141935535101097
# Model saved! (time elapsed: 1008.4966914653778)
# [ Train epoch: 18 ]
# Train accuarcy: 82.97497615028986
# Train average loss: 0.014324165126709977
# [ Validation epoch: 19 ]
# Accuarcy: 87.3202230701497
# Average loss: 0.011493727877530528
# Model saved! (time elapsed: 1064.543095111847)
# [ Train epoch: 19 ]
# Train accuarcy: 82.94562266089382
# Train average loss: 0.014492610786712956
# [ Validation epoch: 20 ]
# Accuarcy: 87.96595245083651
# Average loss: 0.010962819752190727
# Model saved! (time elapsed: 1120.5771708488464)
# [ Train epoch: 20 ]
# Train accuarcy: 83.36390988478756
# Train average loss: 0.014021456331274888
# [ Validation epoch: 21 ]
# Accuarcy: 87.6430877604931
# Average loss: 0.010934485408491427
# Model saved! (time elapsed: 1176.5525619983673)
# [ Train epoch: 21 ]
# Train accuarcy: 83.98767153445365
# Train average loss: 0.013677046207039006
# [ Validation epoch: 22 ]
# Accuarcy: 88.11270912826534
# Average loss: 0.011205443542200273
# Model saved! (time elapsed: 1232.49391579628)
# [ Train epoch: 22 ]
# Train accuarcy: 83.61341454465399
# Train average loss: 0.013903976396549611
# [ Validation epoch: 23 ]
# Accuarcy: 88.40622248312299
# Average loss: 0.010049392569002114
# Model saved! (time elapsed: 1288.4434094429016)
# [ Train epoch: 23 ]
# Train accuarcy: 84.22249944962208
# Train average loss: 0.01332762242435158
# [ Validation epoch: 24 ]
# Accuarcy: 88.17141179923686
# Average loss: 0.011050569360989925
# Model saved! (time elapsed: 1344.5159559249878)
# [ Train epoch: 24 ]
# Train accuarcy: 84.24451456666911
# Train average loss: 0.013455687868644987
# [ Validation epoch: 25 ]
# Accuarcy: 86.70384502494863
# Average loss: 0.012711640194797572
# Model saved! (time elapsed: 1400.5662755966187)
# [ Train epoch: 25 ]
# Train accuarcy: 85.05173552506054
# Train average loss: 0.013233664584932301
# [ Validation epoch: 26 ]
# Accuarcy: 88.08335779277957
# Average loss: 0.01063289316625304
# Model saved! (time elapsed: 1456.622546672821)
# [ Train epoch: 26 ]
# Train accuarcy: 84.67014016291186
# Train average loss: 0.012937242616961163
# [ Validation epoch: 27 ]
# Accuarcy: 88.05400645729381
# Average loss: 0.01054535748446341
# Model saved! (time elapsed: 1512.6548464298248)
# [ Train epoch: 27 ]
# Train accuarcy: 84.84626109928818
# Train average loss: 0.01287252098866479
# [ Validation epoch: 28 ]
# Accuarcy: 89.19870854123863
# Average loss: 0.010300897373450198
# Model saved! (time elapsed: 1568.5828454494476)
# [ Train epoch: 28 ]
# Train accuarcy: 85.04439715271153
# Train average loss: 0.012630687983490763
# [ Validation epoch: 29 ]
# Accuarcy: 88.52362782506604
# Average loss: 0.010554869175132223
# Model saved! (time elapsed: 1624.550882101059)
# [ Train epoch: 29 ]
# Train accuarcy: 85.56542158949145
# Train average loss: 0.012323715384860132
# [ Validation epoch: 30 ]
# Accuarcy: 87.26152039917817
# Average loss: 0.010899315978254711
# Model saved! (time elapsed: 1680.5771353244781)

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(epoch)], [i[0] for i in train_result])
plt.plot([i for i in range(epoch)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(epoch)], [i[1] for i in train_result])
plt.plot([i for i in range(epoch)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns


net = ResNet18()
net = net.to(device)

file_name = "./checkpoint/ResNet18.pt"
checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

# 평가 데이터셋을 이용해 혼동 행렬(confusion matrix) 계산하기
confusion_matrix = get_confusion_matrix(net, 6, val_dataloader)
print("[ 각 클래스당 데이터 개수 ]")
print(confusion_matrix.sum(1))

print("[ 혼동 행렬(confusion matrix) 시각화 ]")
res = pd.DataFrame(confusion_matrix.numpy(), index = [i for i in range(6)], columns = [i for i in range(6)])
res.index.name = 'True label'
res.columns.name = 'Predicted label'
plt.figure(figsize = (10, 7))
sns.heatmap(res, annot=True, fmt="d", cmap='Blues')
plt.show()

print("[ 각 클래스에 따른 정확도 ]")
# (각 클래스마다 정답 개수 / 각 클래스마다 데이터의 개수)
print(confusion_matrix.diag() / confusion_matrix.sum(1))

print("[ 전체 평균 정확도 ]")
print(confusion_matrix.diag().sum() / confusion_matrix.sum())
# Out:
# [ 각 클래스당 데이터 개수 ]
# tensor([523, 540, 594, 599, 560, 591])
# [ 혼동 행렬(confusion matrix) 시각화 ]
# [ 각 클래스에 따른 정확도 ]
# tensor([0.9446, 0.9667, 0.8114, 0.8564, 0.8946, 0.7800])
# [ 전체 평균 정확도 ]
# tensor(0.8726)

# %% [markdown]
# #### <b>(알아보기) Input Mixup 살펴보기</b>
#
# * Mixup은 대표적인 데이터 증진(data augmentation) 기법으로 정확도 향상에 도움이 됩니다.
#     * 일반적으로 Mixup을 사용하는 경우 더 많은 횟수(1.5배가량)의 epoch이 요구됩니다.

# %%
mixup_alpha = 1.0


def mixup_data(x, y):
    lam = np.random.beta(mixup_alpha, mixup_alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()
    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)


def train_with_mixup(net, epoch, optimizer, criterion, train_dataloader):
    print('[ Train epoch: %d ]' % epoch)
    net.train() # 모델을 학습 모드로 설정
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets) # Mixup 진행
        optimizer.zero_grad() # 기울기(gradient) 초기화

        outputs = net(inputs) # 모델 입력하여 결과 계산
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam) # 손실(loss) 값 계산
        loss.backward() # 역전파를 통해 기울기(gradient) 계산

        optimizer.step() # 계산된 기울기를 이용해 모델 가중치 업데이트
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())

    print('Train accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)
    return (100. * correct / total, train_loss / total)

# %% [markdown]
# ## <b>Problem 6. Mixup 결과 분석하기</b>
#
# * Mixup을 사용하여 ResNet-18에 대하여 50번 epoch만큼 학습을 진행한 뒤에 성능이 얼마나 개선되었는지 쓰세요.
#     * Mixup을 적용했을 때의 검증 정확도(validation accuracy): {답을 쓰세요.}

# %% [markdown]
# #### <b>(알아보기) Transfer Learning 살펴보기</b>
#
# * 전이 학습(Transfer Learning)은 <b>단기간에 우수한 정확도</b>를 얻기 위해 효과적으로 사용할 수 있는 기법입니다.
#     * 본 실습에서는 미세 조정(fine-tuning) 기법을 사용합니다.
#     * 적은 epoch만으로도 빠르게 수렴합니다.
# * 전이 학습을 위해서는, 사전 학습된(pre-trained) 네트워크와 동일한 크기의 입력 차원을 갖도록 <b>데이터셋을 수정</b>해야 합니다.
#     * ResNet 특성상 데이터셋 수정 없이도 동작할 수 있지만, 일반적으로 데이터셋을 수정합니다.
# * (참고) [PyTorch 공식 Transfer Learning 튜토리얼](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html)
# * 기본적인 Transfer Learning을 이용해 91~93%의 정확도를 얻을 수 있습니다.

# %%
transforms_train_transferred = transforms.Compose([
    transforms.RandomResizedCrop((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_val_transferred = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset_transferred = datasets.ImageFolder(train_path, transforms_train_transferred)
val_dataset_transferred = datasets.ImageFolder(val_path, transforms_val_transferred)

train_dataloader_transferred = torch.utils.data.DataLoader(train_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)
val_dataloader_transferred = torch.utils.data.DataLoader(val_dataset_transferred, batch_size=16, shuffle=True, num_workers=2)

print('Training dataset size:', len(train_dataset_transferred))
print('Validation dataset size:', len(val_dataset_transferred))

class_names = train_dataset_transferred.classes
print('Class names:', class_names)
# Out:
# Training dataset size: 13627
# Validation dataset size: 3407
# Class names: ['buildings', 'forests', 'glacier', 'mountains', 'sea', 'street']

# %%
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 10:
        lr /= 8
    if epoch >= 20:
        lr /= 8
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
net = torchvision.models.resnet101(pretrained=True)

# 마지막 레이어의 차원을 6차원으로 조절
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, 6)
net = net.to(device)

epoch = 50
learning_rate = 0.001 # 일반적으로 fine-tuning을 진행할 때는 학습률(learning rate)을 낮게 설정

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

train_result = []
val_result = []

start_time = time.time() # 시작 시간

for i in range(epoch):
    train_acc, train_loss = train(net, i + 1, optimizer, criterion, train_dataloader_transferred) # 학습(training)
    val_acc, val_loss = validate(net, i + 1, val_dataloader_transferred) # 검증(validation)
    adjust_learning_rate(optimizer, i)
    print(f'time elapsed: {time.time() - start_time}, {int(time.time() - start_time) // 60}분 {int(time.time() - start_time) % 60}초')
    print()

    if (i+1) % 5 == 0:
        # 학습된 모델 저장하기
        state = {
            'net': net.state_dict()
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        file_name = "ResNet101Transferred_{}.pt".format(i+1)
        torch.save(state, './checkpoint/' + file_name)
        print(f'Model saved! ({file_name})')

        # 현재 epoch에서의 정확도(accuracy)와 손실(loss) 값 저장하기
        train_result.append((train_acc, train_loss))
        val_result.append((val_acc, val_loss))
# Out:
# [ Train epoch: 1 ]
# Train accuracy:78.704043
# Train average loss:0.035956
# [ Validation epoch: 1 ]
# Accuracy:90.989140
# Average loss:0.016827
# time elapsed: 237.9656264781952, 3분 57초
# [ Train epoch: 2 ]
# Train accuracy:85.073751
# Train average loss:0.026255
# [ Validation epoch: 2 ]
# Accuracy:90.548870
# Average loss:0.016913
# time elapsed: 482.5017726421356, 8분 2초
# [ Train epoch: 3 ]
# Train accuracy:86.490057
# Train average loss:0.022794
# [ Validation epoch: 3 ]
# Accuracy:92.368653
# Average loss:0.014447
# time elapsed: 732.3034989833832, 12분 12초
# [ Train epoch: 4 ]
# Train accuracy:87.201879
# Train average loss:0.021471
# [ Validation epoch: 4 ]
# Accuracy:90.813032
# Average loss:0.015899
# time elapsed: 984.2308325767517, 16분 24초
# [ Train epoch: 5 ]
# Train accuracy:88.823659
# Train average loss:0.019434
# [ Validation epoch: 5 ]
# Accuracy:93.131787
# Average loss:0.013039
# time elapsed: 1231.0236415863037, 20분 31초
# Model saved! (ResNet101Transferred_5.pt)
#
# [ Train epoch: 6 ]
# Train accuracy:89.102517
# Train average loss:0.018312
# [ Validation epoch: 6 ]
# Accuracy:92.398004
# Average loss:0.013777
# time elapsed: 1478.2341656684875, 24분 38초
# [ Train epoch: 7 ]
# Train accuracy:89.513466
# Train average loss:0.017272
# [ Validation epoch: 7 ]
# Accuracy:92.544761
# Average loss:0.014004
# time elapsed: 1726.2046537399292, 28분 46초
# [ Train epoch: 8 ]
# Train accuracy:89.983122
# Train average loss:0.016783
# [ Validation epoch: 8 ]
# Accuracy:92.574112
# Average loss:0.014965
# time elapsed: 1973.555101633072, 32분 53초
# [ Train epoch: 9 ]
# Train accuracy:90.416086
# Train average loss:0.016132
# [ Validation epoch: 9 ]
# Accuracy:91.341356
# Average loss:0.017034
# time elapsed: 2220.6959040164948, 37분 0초
# [ Train epoch: 10 ]
# Train accuracy:90.834373
# Train average loss:0.015139
# [ Validation epoch: 10 ]
# Accuracy:93.278544
# Average loss:0.013300
# time elapsed: 2467.8232095241547, 41분 7초
# Model saved! (ResNet101Transferred_10.pt)
#
# [ Train epoch: 11 ]
# Train accuracy:91.370074
# Train average loss:0.014611
# [ Validation epoch: 11 ]
# Accuracy:92.163193
# Average loss:0.015465
# time elapsed: 2715.3026835918427, 45분 15초
# [ Train epoch: 12 ]
# Train accuracy:93.219344
# Train average loss:0.011603
# [ Validation epoch: 12 ]
# Accuracy:93.748166
# Average loss:0.013103
# time elapsed: 2962.9270577430725, 49분 22초
# [ Train epoch: 13 ]
# Train accuracy:93.586263
# Train average loss:0.011035
# [ Validation epoch: 13 ]
# Accuracy:93.748166
# Average loss:0.012604
# time elapsed: 3210.2778646945953, 53분 30초
# [ Train epoch: 14 ]
# Train accuracy:93.586263
# Train average loss:0.010649
# [ Validation epoch: 14 ]
# Accuracy:93.630760
# Average loss:0.012786
# time elapsed: 3457.8914909362793, 57분 37초
# [ Train epoch: 15 ]
# Train accuracy:94.055918
# Train average loss:0.010263
# [ Validation epoch: 15 ]
# Accuracy:93.865571
# Average loss:0.012605
# time elapsed: 3705.2889873981476, 61분 45초
# Model saved! (ResNet101Transferred_15.pt)
#
# [ Train epoch: 16 ]
# Train accuracy:94.055918
# Train average loss:0.009780
# [ Validation epoch: 16 ]
# Accuracy:93.865571
# Average loss:0.012375
# time elapsed: 3953.024893283844, 65분 53초
# [ Train epoch: 17 ]
# Train accuracy:94.393484
# Train average loss:0.009439
# [ Validation epoch: 17 ]
# Accuracy:93.542706
# Average loss:0.012655
# time elapsed: 4200.299569129944, 70분 0초
# [ Train epoch: 18 ]
# Train accuracy:94.474206
# Train average loss:0.009191
# [ Validation epoch: 18 ]
# Accuracy:93.924274
# Average loss:0.012662
# time elapsed: 4447.618246078491, 74분 7초
# [ Train epoch: 19 ]
# Train accuracy:94.466867
# Train average loss:0.009339
# [ Validation epoch: 19 ]
# Accuracy:93.748166
# Average loss:0.013129
# time elapsed: 4694.557591915131, 78분 14초
# [ Train epoch: 20 ]
# Train accuracy:94.532913
# Train average loss:0.009223
# [ Validation epoch: 20 ]
# Accuracy:93.660112
# Average loss:0.013198
# time elapsed: 4941.74148440361, 82분 21초
# Model saved! (ResNet101Transferred_20.pt)
#
# [ Train epoch: 21 ]
# Train accuracy:94.987892
# Train average loss:0.008822
# [ Validation epoch: 21 ]
# Accuracy:93.689463
# Average loss:0.013735
# time elapsed: 5189.455967903137, 86분 29초
# [ Train epoch: 22 ]
# Train accuracy:94.987892
# Train average loss:0.008601
# [ Validation epoch: 22 ]
# Accuracy:93.865571
# Average loss:0.013372
# time elapsed: 5436.6795399188995, 90분 36초
# [ Train epoch: 23 ]
# Train accuracy:95.420856
# Train average loss:0.008060
# [ Validation epoch: 23 ]
# Accuracy:93.865571
# Average loss:0.013347
# time elapsed: 5683.496108531952, 94분 43초
# [ Train epoch: 24 ]
# Train accuracy:95.046599
# Train average loss:0.008310
# [ Validation epoch: 24 ]
# Accuracy:93.718814
# Average loss:0.013506
# time elapsed: 5930.940270185471, 98분 50초
# [ Train epoch: 25 ]
# Train accuracy:95.097967
# Train average loss:0.008323
# [ Validation epoch: 25 ]
# Accuracy:93.982976
# Average loss:0.013298
# time elapsed: 6178.040405511856, 102분 58초
# Model saved! (ResNet101Transferred_25.pt)
#
# [ Train epoch: 26 ]
# Train accuracy:95.457548
# Train average loss:0.008144
# [ Validation epoch: 26 ]
# Accuracy:93.924274
# Average loss:0.013133
# time elapsed: 6425.851217985153, 107분 5초
# [ Train epoch: 27 ]
# Train accuracy:95.332795
# Train average loss:0.008381
# [ Validation epoch: 27 ]
# Accuracy:93.806868
# Average loss:0.013378
# time elapsed: 6673.368334531784, 111분 13초
# [ Train epoch: 28 ]
# Train accuracy:95.237396
# Train average loss:0.008282
# [ Validation epoch: 28 ]
# Accuracy:93.718814
# Average loss:0.013240
# time elapsed: 6920.722326755524, 115분 20초
# [ Train epoch: 29 ]
# Train accuracy:95.119982
# Train average loss:0.008192
# [ Validation epoch: 29 ]
# Accuracy:93.953625
# Average loss:0.013357
# time elapsed: 7168.353317737579, 119분 28초
# [ Train epoch: 30 ]
# Train accuracy:95.303442
# Train average loss:0.008197
# [ Validation epoch: 30 ]
# Accuracy:93.689463
# Average loss:0.013219
# time elapsed: 7415.776142835617, 123분 35초
# Model saved! (ResNet101Transferred_30.pt)
#
# [ Train epoch: 31 ]
# Train accuracy:95.149336
# Train average loss:0.008296
# [ Validation epoch: 31 ]
# Accuracy:93.894922
# Average loss:0.013330
# time elapsed: 7663.506868124008, 127분 43초
# [ Train epoch: 32 ]
# Train accuracy:94.892493
# Train average loss:0.008518
# [ Validation epoch: 32 ]
# Accuracy:93.836220
# Average loss:0.013281
# time elapsed: 7910.832317113876, 131분 50초
# [ Train epoch: 33 ]
# Train accuracy:95.435532
# Train average loss:0.007854
# [ Validation epoch: 33 ]
# Accuracy:93.982976
# Average loss:0.013425
# time elapsed: 8158.264046669006, 135분 58초
# [ Train epoch: 34 ]
# Train accuracy:95.112644
# Train average loss:0.008326
# [ Validation epoch: 34 ]
# Accuracy:93.601409
# Average loss:0.013761
# time elapsed: 8405.786475419998, 140분 5초
# [ Train epoch: 35 ]
# Train accuracy:95.127321
# Train average loss:0.008408
# [ Validation epoch: 35 ]
# Accuracy:93.953625
# Average loss:0.013374
# time elapsed: 8653.302946805954, 144분 13초
# Model saved! (ResNet101Transferred_35.pt)
#
# [ Train epoch: 36 ]
# Train accuracy:95.230058
# Train average loss:0.008096
# [ Validation epoch: 36 ]
# Accuracy:93.748166
# Average loss:0.013333
# time elapsed: 8901.198378801346, 148분 21초
# [ Train epoch: 37 ]
# Train accuracy:95.230058
# Train average loss:0.008254
# [ Validation epoch: 37 ]
# Accuracy:93.748166
# Average loss:0.013332
# time elapsed: 9149.157260656357, 152분 29초
# [ Train epoch: 38 ]
# Train accuracy:95.325457
# Train average loss:0.007889
# [ Validation epoch: 38 ]
# Accuracy:93.748166
# Average loss:0.013378
# time elapsed: 9397.275941848755, 156분 37초
# [ Train epoch: 39 ]
# Train accuracy:95.237396
# Train average loss:0.008132
# [ Validation epoch: 39 ]
# Accuracy:93.718814
# Average loss:0.013400
# time elapsed: 9644.814443349838, 160분 44초
# [ Train epoch: 40 ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-8cb3a659a141> in <cell line: 19>()
#      18
#      19 for i in range(epoch):
# ---> 20     train_acc, train_loss = train(net, i + 1, optimizer, criterion, train_dataloader_transferred) # 학습(training)
#      21     val_acc, val_loss = validate(net, i + 1, val_dataloader_transferred) # 검증(validation)
#      22     adjust_learning_rate(optimizer, i)
#
# <ipython-input-8-54207099c29b> in train(net, epoch, optimizer, criterion, train_dataloader, device)
#       9         optimizer.zero_grad() # 기울기(gradient) 초기화
#      10
# ---> 11         outputs = net(inputs) # 모델 입력하여 결과 계산
#      12         loss = criterion(outputs, targets) # 손실(loss) 값 계산
#      13         loss.backward() # 역전파를 통해 기울기(gradient) 계산
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/resnet.py in forward(self, x)
#     283
#     284     def forward(self, x: Tensor) -> Tensor:
# --> 285         return self._forward_impl(x)
#     286
#     287
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/resnet.py in _forward_impl(self, x)
#     273         x = self.layer1(x)
#     274         x = self.layer2(x)
# --> 275         x = self.layer3(x)
#     276         x = self.layer4(x)
#     277
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     213     def forward(self, input):
#     214         for module in self:
# --> 215             input = module(input)
#     216         return input
#     217
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/resnet.py in forward(self, x)
#     150         out = self.conv2(out)
#     151         out = self.bn2(out)
# --> 152         out = self.relu(out)
#     153
#     154         out = self.conv3(out)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#      99
#     100     def forward(self, input: Tensor) -> Tensor:
# --> 101         return F.relu(input, inplace=self.inplace)
#     102
#     103     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in relu(input, inplace)
#    1467         return handle_torch_function(relu, (input,), input, inplace=inplace)
#    1468     if inplace:
# -> 1469         result = torch.relu_(input)
#    1470     else:
#    1471         result = torch.relu(input)
#
# KeyboardInterrupt:

# %% [markdown]
# ## <b>Problem 7. State-of-the-Art 성능 만들기</b>
#
# * SOTA 수준의 성능을 만들어 보세요.
# * (참고) Transfer Learning과 Mixup을 함께 사용해 보세요.
#     * 더 큰 규모의 사전 학습된 모델(ResNet-50 이상)을 이용해 보세요.
# * (참고) learning rate scheduler를 사용해 보세요.
#
# <pre>
# def adjust_learning_rate(optimizer, epoch):
#     lr = learning_rate
#     if epoch >= 20:
#         lr /= 8
#     if epoch >= 40:
#         lr /= 8
#     for param_group in optimizer.param_groups:
#         param_group['lr'] = lr
# </pre>
#
# * 대회(competition)에 참여하고 있다고 생각하고, <b>94% 이상의 정확도</b>를 만들어 보세요.
#     * 내 모델의 검증 정확도(validation accuracy): {답을 쓰세요.}

# %%
# 정확도(accuracy) 커브 시각화
plt.subplot(211)
plt.plot([i for i in range(7)], [i[0] for i in train_result])
plt.plot([i for i in range(7)], [i[0] for i in val_result])
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])

# 손실(loss) 커브 시각화
plt.subplot(212)
plt.plot([i for i in range(7)], [i[1] for i in train_result])
plt.plot([i for i in range(7)], [i[1] for i in val_result])
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train", "val"])

plt.tight_layout()
plt.show()

# %%
train_result
# Out:
# [(88.82365891245321, 0.019434266226763787),
#  (90.83437293608277, 0.015139137915233558),
#  (94.05591839729948, 0.010262831608632445),
#  (94.53291259998532, 0.009222850985915276),
#  (95.09796727085933, 0.008323455279190133),
#  (95.3034416966317, 0.008197071810420476),
#  (95.12732076025537, 0.008407504379617669)]
